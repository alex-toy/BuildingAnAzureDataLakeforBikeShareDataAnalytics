# %% [markdown]
# # Create time dimension

# %%
min_date_qry = spark.sql('''
    SELECT MIN(started_at) as started_at FROM trips
''')
min_date = min_date_qry.first().asDict()['started_at']

max_date_qry = spark.sql('''
    SELECT DATEADD(year, 5, MAX(started_at)) as started_at FROM trips
''')
max_date = max_date_qry.first().asDict()['started_at']

expression = f"sequence(to_date('{min_date}'), to_date('{max_date}'), interval 1 day)"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql import functions as f


dim_time = spark.createDataFrame([(1,)], ["time_id"])

dim_time = dim_time.withColumn("dateinit", f.explode(f.expr(expression)))
dim_time = dim_time.withColumn("date", f.to_timestamp(dim_time.dateinit, "yyyy-MM-dd"))
dim_time = dim_time \
    .withColumn("year", f.year(dim_time.date)) \
    .withColumn("quarter", f.quarter(dim_time.date)) \
    .withColumn("month", f.month(dim_time.date)) \
    .withColumn("day", f.dayofweek(dim_time.date)) \
    .withColumn("time_id", dim_time.date.cast(StringType())) \
    .drop(col("dateinit"))

dim_time.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+-------------------+----+-------+-----+---+
#             time_id|               date|year|quarter|month|day|
# +-------------------+-------------------+----+-------+-----+---+
# 2021-02-01 00:00:00|2021-02-01 00:00:00|2021|      1|    2|  2|
# 2021-02-02 00:00:00|2021-02-02 00:00:00|2021|      1|    2|  3|
# 2021-02-03 00:00:00|2021-02-03 00:00:00|2021|      1|    2|  4|
# 2021-02-04 00:00:00|2021-02-04 00:00:00|2021|      1|    2|  5|
# 2021-02-05 00:00:00|2021-02-05 00:00:00|2021|      1|    2|  6|
# +-------------------+-------------------+----+-------+-----+---+
# only showing top 5 rows
#
# </div>

# %%
dim_time.agg({'year': 'max'}).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+
# max(year)|
# +---------+
#      2027|
# +---------+
#
# </div>

# %%
dim_time.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("dim_time")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
select * from dim_time limit 5
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>time_id</th><th>date</th><th>year</th><th>quarter</th><th>month</th><th>day</th></tr></thead><tbody><tr><td>2021-02-01 00:00:00</td><td>2021-02-01T00:00:00.000+0000</td><td>2021</td><td>1</td><td>2</td><td>2</td></tr><tr><td>2021-02-02 00:00:00</td><td>2021-02-02T00:00:00.000+0000</td><td>2021</td><td>1</td><td>2</td><td>3</td></tr><tr><td>2021-02-03 00:00:00</td><td>2021-02-03T00:00:00.000+0000</td><td>2021</td><td>1</td><td>2</td><td>4</td></tr><tr><td>2021-02-04 00:00:00</td><td>2021-02-04T00:00:00.000+0000</td><td>2021</td><td>1</td><td>2</td><td>5</td></tr><tr><td>2021-02-05 00:00:00</td><td>2021-02-05T00:00:00.000+0000</td><td>2021</td><td>1</td><td>2</td><td>6</td></tr></tbody></table></div>

# %%
dim_time.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- time_id: string (nullable = true)
# -- date: timestamp (nullable = true)
# -- year: integer (nullable = true)
# -- quarter: integer (nullable = true)
# -- month: integer (nullable = true)
# -- day: integer (nullable = true)
#
# </div>

# %% [markdown]
# # create payment fact table

# %%
fact_payment = spark.sql('''
    SELECT
        payment_id,
        payments.amount,
        payments.rider_id,
        dim_time.time_id
    FROM payments
    JOIN dim_time ON dim_time.date = payments.date
''')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
fact_payment.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+------+--------+-------------------+
# payment_id|amount|rider_id|            time_id|
# +----------+------+--------+-------------------+
#         22|   9.0|    1000|2021-02-01 00:00:00|
#         23|   9.0|    1000|2021-03-01 00:00:00|
#         24|   9.0|    1000|2021-04-01 00:00:00|
#         25|   9.0|    1000|2021-05-01 00:00:00|
#         26|   9.0|    1000|2021-06-01 00:00:00|
#         27|   9.0|    1000|2021-07-01 00:00:00|
#         28|   9.0|    1000|2021-08-01 00:00:00|
#         29|   9.0|    1000|2021-09-01 00:00:00|
#         30|   9.0|    1000|2021-10-01 00:00:00|
#         31|   9.0|    1000|2021-11-01 00:00:00|
#         32|   9.0|    1000|2021-12-01 00:00:00|
#         33|   9.0|    1000|2022-01-01 00:00:00|
#         34|   9.0|    1000|2022-02-01 00:00:00|
#         62|  6.56|    1003|2021-02-01 00:00:00|
#         63|   7.4|    1003|2021-03-01 00:00:00|
#         64| 18.31|    1003|2021-04-01 00:00:00|
#         65| 14.48|    1003|2021-05-01 00:00:00|
#         66|   6.5|    1003|2021-06-01 00:00:00|
#         67| 12.35|    1003|2021-07-01 00:00:00|
#         68| 22.84|    1003|2021-08-01 00:00:00|
# +----------+------+--------+-------------------+
# only showing top 20 rows
#
# </div>

# %%
fact_payment.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("fact_payment")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
select * from fact_payment limit 5
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>payment_id</th><th>amount</th><th>rider_id</th><th>time_id</th></tr></thead><tbody><tr><td>22</td><td>9.0</td><td>1000</td><td>2021-02-01 00:00:00</td></tr><tr><td>23</td><td>9.0</td><td>1000</td><td>2021-03-01 00:00:00</td></tr><tr><td>24</td><td>9.0</td><td>1000</td><td>2021-04-01 00:00:00</td></tr><tr><td>25</td><td>9.0</td><td>1000</td><td>2021-05-01 00:00:00</td></tr><tr><td>26</td><td>9.0</td><td>1000</td><td>2021-06-01 00:00:00</td></tr></tbody></table></div>

# %% [markdown]
# # create trip fact

# %%
fact_trip = spark.sql('''
    SELECT 
        trips.trip_id,
        riders.rider_id,
        trips.start_station_id, 
        trips.end_station_id, 
        start_time.time_id                                                  AS start_time_id,
        end_time.time_id                                                    AS end_time_id,
        trips.rideable_type,
        DATEDIFF(hour, trips.started_at, trips.ended_at)                    AS duration,
        DATEDIFF(year, riders.birthday, trips.started_at)                     AS rider_age

    FROM trips
    JOIN riders                     ON riders.rider_id = trips.rider_id
    JOIN dim_time AS start_time     ON start_time.date = trips.started_at
    JOIN dim_time AS end_time       ON end_time.date = trips.ended_at
''')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
fact_trip.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+--------+----------------+--------------+-------------+-----------+-------------+--------+---------+
# trip_id|rider_id|start_station_id|end_station_id|start_time_id|end_time_id|rideable_type|duration|rider_age|
# +-------+--------+----------------+--------------+-------------+-----------+-------------+--------+---------+
# +-------+--------+----------------+--------------+-------------+-----------+-------------+--------+---------+
#
# </div>

# %%
fact_trip.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("fact_trip")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
SELECT * from fact_trip limit 2
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>trip_id</th><th>rider_id</th><th>start_station_id</th><th>end_station_id</th><th>start_time_id</th><th>end_time_id</th><th>rideable_type</th><th>duration</th><th>rider_age</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SELECT * from dim_time limit 2
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>time_id</th><th>date</th><th>year</th><th>quarter</th><th>month</th><th>day</th></tr></thead><tbody><tr><td>2021-02-01 00:00:00</td><td>2021-02-01T00:00:00.000+0000</td><td>2021</td><td>1</td><td>2</td><td>2</td></tr><tr><td>2021-02-02 00:00:00</td><td>2021-02-02T00:00:00.000+0000</td><td>2021</td><td>1</td><td>2</td><td>3</td></tr></tbody></table></div>

# %% [markdown]
# # create rider dimension

# %%
dim_rider = spark.sql('''
    SELECT 
        rider_id, firstName, lastName, address, birthday, startDate, endDate, isMember
    FROM riders
''')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dim_rider.show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+---------+--------+-------------------+-------------------+-------------------+-------------------+--------+
# rider_id|firstName|lastName|            address|           birthday|          startDate|            endDate|isMember|
# +--------+---------+--------+-------------------+-------------------+-------------------+-------------------+--------+
#     1000|    Diana|   Clark|1200 Alyssa Squares|1989-02-13 00:00:00|2019-04-23 00:00:00|               null|    true|
#     1001| Jennifer|   Smith|    397 Diana Ferry|1976-08-10 00:00:00|2019-11-01 00:00:00|2020-09-01 00:00:00|    true|
# +--------+---------+--------+-------------------+-------------------+-------------------+-------------------+--------+
# only showing top 2 rows
#
# </div>

# %%
dim_rider.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("dim_rider")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
SELECT * from dim_rider limit 2
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>rider_id</th><th>firstName</th><th>lastName</th><th>address</th><th>birthday</th><th>startDate</th><th>endDate</th><th>isMember</th></tr></thead><tbody><tr><td>1000</td><td>Diana</td><td>Clark</td><td>1200 Alyssa Squares</td><td>1989-02-13T00:00:00.000+0000</td><td>2019-04-23T00:00:00.000+0000</td><td>null</td><td>true</td></tr><tr><td>1001</td><td>Jennifer</td><td>Smith</td><td>397 Diana Ferry</td><td>1976-08-10T00:00:00.000+0000</td><td>2019-11-01T00:00:00.000+0000</td><td>2020-09-01T00:00:00.000+0000</td><td>true</td></tr></tbody></table></div>

# %% [markdown]
# # create station dimension

# %%
dim_station = spark.sql('''
    SELECT station_id, name, latitude , longitude FROM stations
''')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dim_station.show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------+--------------------+-----------------+------------------+
#   station_id|                name|         latitude|         longitude|
# +------------+--------------------+-----------------+------------------+
#          525|Glenwood Ave &amp; To...|        42.012701|-87.66605799999999|
# KA1503000012|  Clark St &amp; Lake St|41.88579466666667|-87.63110066666668|
# +------------+--------------------+-----------------+------------------+
# only showing top 2 rows
#
# </div>

# %%
dim_station.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("dim_station")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
SELECT * from dim_station limit 2
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>station_id</th><th>name</th><th>latitude</th><th>longitude</th></tr></thead><tbody><tr><td>525</td><td>Glenwood Ave & Touhy Ave</td><td>42.012701</td><td>-87.66605799999999</td></tr><tr><td>KA1503000012</td><td>Clark St & Lake St</td><td>41.88579466666667</td><td>-87.63110066666668</td></tr></tbody></table></div>

# %% [markdown]
# # create payment dimension

# %%
dim_payment = spark.sql('''
    SELECT
        payment_id,
        payments.amount,
        payments.rider_id,
        dim_time.time_id
    FROM payments
    JOIN dim_time ON dim_time.date = payments.date
''')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dim_payment.show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+------+--------+-------------------+
# payment_id|amount|rider_id|            time_id|
# +----------+------+--------+-------------------+
#         22|   9.0|    1000|2021-02-01 00:00:00|
#         23|   9.0|    1000|2021-03-01 00:00:00|
# +----------+------+--------+-------------------+
# only showing top 2 rows
#
# </div>

# %%
dim_payment.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("dim_payment")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
SELECT * from dim_payment limit 2
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>payment_id</th><th>amount</th><th>rider_id</th><th>time_id</th></tr></thead><tbody><tr><td>22</td><td>9.0</td><td>1000</td><td>2021-02-01 00:00:00</td></tr><tr><td>23</td><td>9.0</td><td>1000</td><td>2021-03-01 00:00:00</td></tr></tbody></table></div>
