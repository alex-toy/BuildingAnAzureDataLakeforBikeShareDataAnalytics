# %% [markdown]
# # Spark SQL Examples

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType
from pyspark.sql.types import IntegerType
from pyspark.sql.functions import desc
from pyspark.sql.functions import asc
from pyspark.sql.functions import sum as Fsum

import datetime

import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
path = "/FileStore/tables/riders.csv"
df_riders = spark.read \
    .option("inferSchema", "true") \
    .option("header", "false") \
    .option("sep", ",") \
    .format("csv") \
    .load(path) \
    .withColumnRenamed("_c0","rider_id") \
    .withColumnRenamed("_c1","firstName")\
    .withColumnRenamed("_c2","lastName")\
    .withColumnRenamed("_c3","address")\
    .withColumnRenamed("_c4","birthday")\
    .withColumnRenamed("_c5","startDate")\
    .withColumnRenamed("_c6","endDate")\
    .withColumnRenamed("_c7","isMember")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # Create a View And Run Queries
#
# The code below creates a temporary view against which you can run SQL queries.

# %%
df_riders.createOrReplaceTempView("riders")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
SELECT * FROM riders LIMIT 2
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>rider_id</th><th>firstName</th><th>lastName</th><th>address</th><th>birthday</th><th>startDate</th><th>endDate</th><th>isMember</th></tr></thead><tbody><tr><td>1000</td><td>Diana</td><td>Clark</td><td>1200 Alyssa Squares</td><td>1989-02-13T00:00:00.000+0000</td><td>2019-04-23T00:00:00.000+0000</td><td>null</td><td>true</td></tr><tr><td>1001</td><td>Jennifer</td><td>Smith</td><td>397 Diana Ferry</td><td>1976-08-10T00:00:00.000+0000</td><td>2019-11-01T00:00:00.000+0000</td><td>2020-09-01T00:00:00.000+0000</td><td>true</td></tr></tbody></table></div>

# %%
# %sql 

SELECT COUNT(*) FROM riders
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>75000</td></tr></tbody></table></div>

# %%
# %sql
SELECT rider_id, firstName, lastName, address, birthday, startDate, endDate, isMember
FROM riders 
WHERE rider_id == '1046'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>rider_id</th><th>firstName</th><th>lastName</th><th>address</th><th>birthday</th><th>startDate</th><th>endDate</th><th>isMember</th></tr></thead><tbody><tr><td>1046</td><td>Brianna</td><td>Flores</td><td>351 Bill Curve</td><td>2005-11-09T00:00:00.000+0000</td><td>2020-07-08T00:00:00.000+0000</td><td>null</td><td>true</td></tr></tbody></table></div>

# %%
# %sql

SELECT count(*), isMember
FROM riders 
GROUP BY isMember
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th><th>isMember</th></tr></thead><tbody><tr><td>60124</td><td>true</td></tr><tr><td>14876</td><td>false</td></tr></tbody></table></div>

# %% [markdown]
# # User Defined Functions

# %%
spark.udf.register("get_day", lambda x: x.day if not x is None else 0, IntegerType())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: &lt;function __main__.&lt;lambda&gt;(x)&gt;</div>

# %%
# %sql 

SELECT *, get_day(startDate) AS day
FROM riders 
LIMIT 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>rider_id</th><th>firstName</th><th>lastName</th><th>address</th><th>birthday</th><th>startDate</th><th>endDate</th><th>isMember</th><th>day</th></tr></thead><tbody><tr><td>1000</td><td>Diana</td><td>Clark</td><td>1200 Alyssa Squares</td><td>1989-02-13T00:00:00.000+0000</td><td>2019-04-23T00:00:00.000+0000</td><td>null</td><td>true</td><td>23</td></tr></tbody></table></div>

# %%
count_members_per_day = spark.sql('''
    SELECT get_day(startDate) AS day, count(*) AS countMembers
    FROM riders
    WHERE isMember = true
    GROUP BY day
    ORDER BY day ASC
''')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
count_members_per_day.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+------------+
# day|countMembers|
# +---+------------+
#   1|        1972|
#   2|        1987|
#   3|        1957|
#   4|        2037|
#   5|        2011|
#   6|        2055|
#   7|        1929|
#   8|        1950|
#   9|        1972|
#  10|        2016|
#  11|        2043|
#  12|        2024|
#  13|        1939|
#  14|        1978|
#  15|        1958|
#  16|        1924|
#  17|        1976|
#  18|        1917|
#  19|        1969|
#  20|        1899|
# +---+------------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# # Converting Results to Pandas

# %%
count_members_per_day_pd = count_members_per_day.toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(count_members_per_day_pd)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>day</th><th>countMembers</th></tr></thead><tbody><tr><td>1</td><td>1972</td></tr><tr><td>2</td><td>1987</td></tr><tr><td>3</td><td>1957</td></tr><tr><td>4</td><td>2037</td></tr><tr><td>5</td><td>2011</td></tr><tr><td>6</td><td>2055</td></tr><tr><td>7</td><td>1929</td></tr><tr><td>8</td><td>1950</td></tr><tr><td>9</td><td>1972</td></tr><tr><td>10</td><td>2016</td></tr><tr><td>11</td><td>2043</td></tr><tr><td>12</td><td>2024</td></tr><tr><td>13</td><td>1939</td></tr><tr><td>14</td><td>1978</td></tr><tr><td>15</td><td>1958</td></tr><tr><td>16</td><td>1924</td></tr><tr><td>17</td><td>1976</td></tr><tr><td>18</td><td>1917</td></tr><tr><td>19</td><td>1969</td></tr><tr><td>20</td><td>1899</td></tr><tr><td>21</td><td>1944</td></tr><tr><td>22</td><td>1982</td></tr><tr><td>23</td><td>1997</td></tr><tr><td>24</td><td>1956</td></tr><tr><td>25</td><td>1903</td></tr><tr><td>26</td><td>1974</td></tr><tr><td>27</td><td>1988</td></tr><tr><td>28</td><td>1907</td></tr><tr><td>29</td><td>1914</td></tr><tr><td>30</td><td>1813</td></tr><tr><td>31</td><td>1233</td></tr></tbody></table></div>
